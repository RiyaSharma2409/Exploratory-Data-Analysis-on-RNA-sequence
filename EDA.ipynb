# %% [markdown]
# # **1. Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **2. Reading the dataset.**

# %%
df = pd.read_excel('/content/HRNACountsDeseq2log2_data_18sub.xlsx')

# %% [markdown]
# # **3. Performing EDA**

# %% [markdown]
# **1. Dataset Summary**

# %%
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#   Unnamed: 0   G002-D0   G002-D1   G003-D0   G003-D1   G006-D0   G006-D1  \
# 0          -  3.636978  3.504331  3.440846  3.527306  3.446048  3.186203
# 1       A1BG  2.267091  2.923133  2.454559  3.003589  3.209249  2.678390
# 2   A1BG-AS1  6.818431  6.782951  6.253393  6.428219  6.545124  6.893979
# 3        A2M  3.307167  4.500556  4.098726  3.823990  3.649405  3.858332
# 4    A2M-AS1  4.577798  5.306290  4.847247  5.596473  5.283328  4.661428
#
#     G010-D0   G010-D1   G011-D0  ...   G029-D0   G029-D1   G031-D0   G031-D1  \
# 0  3.374887  3.391911  3.509844  ...  3.559989  3.415553  3.512467  3.511431
# 1  2.777933  1.944526  1.530722  ...  2.201013  3.278495  2.258864  3.249768
# 2  5.649989  6.055924  6.548065  ...  6.932313  6.680043  6.071624  5.728425
# 3  3.005477  3.930318  3.384950  ...  4.247176  4.997542  3.512467  4.507998
# 4  4.303621  4.452430  4.827560  ...  5.648838  4.953194  4.509083  3.511431
#
# ...

# %%
df.rename(columns={'Unnamed: 0': 'Gene Names'}, inplace=True)
df['Gene Names']
# Out:
# 0               -
# 1            A1BG
# 2        A1BG-AS1
# 3             A2M
# 4         A2M-AS1
#            ...
# 20009      ZYG11B
# 20010         ZYX
# 20011       ZZEF1
# 20012        ZZZ3
# 20013     snoZ196
# Name: Gene Names, Length: 20014, dtype: object

# %%
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20014 entries, 0 to 20013
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gene Names  20014 non-null  object
#  1   G002-D0     20014 non-null  float64
#  2   G002-D1     20014 non-null  float64
#  3   G003-D0     20014 non-null  float64
#  4   G003-D1     20014 non-null  float64
#  5   G006-D0     20014 non-null  float64
#  6   G006-D1     20014 non-null  float64
#  7   G010-D0     20014 non-null  float64
#  8   G010-D1     20014 non-null  float64
#  9   G011-D0     20014 non-null  float64
#  10  G011-D1     20014 non-null  float64
#  11  G012-D0     20014 non-null  float64
#  12  G012-D1     20014 non-null  float64
#  13  G017-D0     20014 non-null  float64
#  14  G017-D1     20014 non-null  float64
#  15  G018-D0     20014 non-null  float64
#  16  G018-D1     20014 non-null  float64
#  17  G019-D0     20014 non-null  float64
# ...

# %%
print("\nSummary Statistics:")
print(df.describe(include='all'))
# Out:
# Summary Statistics:
#        Gene Names       G002-D0       G002-D1       G003-D0       G003-D1  \
# count       20014  20014.000000  20014.000000  20014.000000  20014.000000
# unique      20014           NaN           NaN           NaN           NaN
# top       snoZ196           NaN           NaN           NaN           NaN
# freq            1           NaN           NaN           NaN           NaN
# mean          NaN      7.112905      7.113724      7.102358      7.137731
# std           NaN      3.881335      3.879425      3.852518      3.801834
# min           NaN      0.000000      0.000000      0.000000      0.000000
# 25%           NaN      3.777338      3.725646      3.760016      3.823990
# 50%           NaN      7.657106      7.667118      7.656562      7.719185
# 75%           NaN     10.192883     10.198151     10.200543     10.193960
# max           NaN     21.471017     19.329229     21.175573     19.346264
#
# ...

# %% [markdown]
# **2. Checking missing values**

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Gene Names    0
# G002-D0       0
# G002-D1       0
# G003-D0       0
# G003-D1       0
# G006-D0       0
# G006-D1       0
# G010-D0       0
# G010-D1       0
# G011-D0       0
# G011-D1       0
# G012-D0       0
# G012-D1       0
# G017-D0       0
# G017-D1       0
# G018-D0       0
# G018-D1       0
# G019-D0       0
# G019-D1       0
# G020-D0       0
# G020-D1       0
# G023-D0       0
# G023-D1       0
# G024-D0       0
# G024-D1       0
# G025-D0       0
# G025-D1       0
# G029-D0       0
# G029-D1       0
# G031-D0       0
# G031-D1       0
# S006-D0       0
# S006-D1       0
# S009-D0       0
# S009-D1       0
# S051-D0       0
# S051-D1       0
# dtype: int64

# %% [markdown]
# **3. Univariate Analysis**

# %%
df.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# **4. Bivariate Analysis**

# %%
sns.scatterplot(data=df, x='G002-D0', y='Gene Names')
plt.title("Scatter plot of G002-D0 vs Gene Names")
plt.show()

# %% [markdown]
# **5. Correlation Analysis**

# %%
# Compute correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
#  **6. Outlier Detection**

# %%
numeric_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(15, len(numeric_cols) * 3))

for i, col in enumerate(numeric_cols):
    plt.subplot(len(numeric_cols), 1, i+1)
    sns.boxplot(x=df[col], color='skyblue')
    plt.title(f'Boxplot for {col}')
    plt.tight_layout()

plt.show()
